# %%
import poblacionmendeliana

# %%
# ?poblacionmendeliana.scipy

# %%
import scipy

# %%
poblacionmendeliana.creando_poblacion (N= 500, p= 0.22)
# Out:
# [('a', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
# ...

# %%
mi_pob= crando_poblacion= (500, 0.22)
